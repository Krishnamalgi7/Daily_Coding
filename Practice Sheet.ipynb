# %%
nums = [1, 2, 0, 4, 3, 0, 0, 3, 5, 1]

i = 0

if len(nums) ==1:
    print(nums[0])
i=0
while i < len(nums):
    if nums[i]==0:
        break
    i=i+1

if i ==len(nums):
    print("No zero elements")

j=j+1

while j<len(nums):
    if nums[j]==0:
        nums[i],nums[j] = nums[j],nums[i]
        i=i+1
    j=j+1
# Out:
# [9, 0, 6, 10, 7, 5, -2, 3]

# %%
9
